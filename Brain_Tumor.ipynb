# %% [markdown]
# <div dir=ltr align=center>In the name of God</div>
# <br>
# <font size=6><div dir=ltr align=center>
# <font size=5>
# Intelligent Analysis of
# Biomedical Images
# <br>
# <font size=4>
# sharif university of technology, CE department
# </font>
# <br>
# <font size=3>
# Prof. Rohban
# </font>
# <br>
# <font size=3>
# Designed By: Reza Vahidimajd
# </font>
# <br>
# <br>
# <font size=6>
# Homework 2
# </font><br>
# <font size=4>

# %% [markdown]
# In the following notebook, we aims to develop a Convolutional Neural Network (CNN) using the PyTorch framework that can accurately detect and classify Brain Tumors from MRI scans. The CNN will be trained on a large dataset of labeled brain tumor images to learn the patterns and features associated with different tumor types.

# %% [markdown]
# ## <b>1 <span style='color:#e61227'>|</span> reuirements and libraries</b>
#
# Feel free to add any other library you need.

# %%
# !pip install split-folders
# !pip install torch-summary
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Collecting torch-summary
#   Downloading torch_summary-1.4.5-py3-none-any.whl.metadata (18 kB)
# Downloading torch_summary-1.4.5-py3-none-any.whl (16 kB)
# Installing collected packages: torch-summary
# Successfully installed torch-summary-1.4.5

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style='darkgrid')
import copy
import os
import torch
from PIL import Image
from torch.utils.data import Dataset
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import random_split
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch.nn as nn
from torchvision import utils
from torchvision.datasets import ImageFolder
import splitfolders
from torchsummary import summary
import torch.nn.functional as F
import pathlib
from sklearn.metrics import classification_report
import itertools
from tqdm.notebook import trange, tqdm
from torch import optim
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## <b>2 <span style='color:#e61227'>|</span> Dataset</b>
#
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#e61227'>2.1 |</span></b> Download and load Dataset</b></p>
# </div>

# %%
! gdown 1hwV1mcc-Bm_AY_t_FG8byxKFmhY4uGsh
! unzip brain.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1hwV1mcc-Bm_AY_t_FG8byxKFmhY4uGsh
# From (redirected): https://drive.google.com/uc?id=1hwV1mcc-Bm_AY_t_FG8byxKFmhY4uGsh&confirm=t&uuid=f7177529-f4f1-42e4-9c46-7909bc776b68
# To: /content/brain.zip
# 100% 111M/111M [00:00<00:00, 112MB/s]
# Archive:  brain.zip
#    creating: brain/
#    creating: brain/val/
#    creating: brain/val/Healthy/
#   inflating: brain/val/Healthy/Not Cancer  (710).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1600).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1008).jpg
#   inflating: brain/val/Healthy/Not Cancer  (45).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1208).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1069).jpg
#   inflating: brain/val/Healthy/Not Cancer  (11).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1823).jpg
#   inflating: brain/val/Healthy/Not Cancer  (111).jpg
#   inflating: brain/val/Healthy/Not Cancer  (115).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1615).jpg
#   inflating: brain/val/Healthy/Not Cancer  (203).jpg
#   inflating: brain/val/Healthy/Not Cancer  (130).jpg
#   inflating: brain/val/Healthy/Not Cancer  (838).jpg
#   inflating: brain/val/Healthy/Not Cancer  (826).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1229).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1165).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1173).jpg
#   inflating: brain/val/Healthy/Not Cancer  (311).jpg
#   inflating: brain/val/Healthy/Not Cancer  (726).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1273).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1698).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1536).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1733).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1136).jpg
#   inflating: brain/val/Healthy/Not Cancer  (594).jpg
#   inflating: brain/val/Healthy/Not Cancer  (663).jpg
#   inflating: brain/val/Healthy/Not Cancer  (1261).jpg
#   inflating: brain/val/Healthy/Not Cancer  (
jpg
#   inflating: brain/train/Brain Tumor/Cancer (2405).jpg
#   inflating: brain/train/Brain Tumor/Cancer (772).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2330).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1596).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1843).jpg
#   inflating: brain/train/Brain Tumor/Cancer (777).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1264).jpg
#   inflating: brain/train/Brain Tumor/Cancer (864).jpg
#   inflating: brain/train/Brain Tumor/Cancer (803).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1456).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1026).JPG
#   inflating: brain/train/Brain Tumor/Cancer (1461).jpg
#   inflating: brain/train/Brain Tumor/Cancer (633).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1576).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2239).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2311).jpg
#   inflating: brain/train/Brain Tumor/Cancer (330).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2186).jpg
#   inflating: brain/train/Brain Tumor/Cancer (384).jpg
#   inflating: brain/train/Brain Tumor/Cancer (527).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1006).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1712).jpg
#   inflating: brain/train/Brain Tumor/Cancer (293).jpg
#   inflating: brain/train/Brain Tumor/Cancer (326).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1058).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1010).jpg
#   inflating: brain/train/Brain Tumor/Cancer (402).jpg
#   inflating: brain/train/Brain Tumor/Cancer (23).tif
#   inflating: brain/train/Brain Tumor/Cancer (21).jpg
#   inflating: brain/train/Brain Tumor/Cancer (838).jpg
#   inflating: brain/train/Brain Tumor/Cancer (816).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1404).jpg
#   inflating: brain/train/Brain Tumor/Cancer (797).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1888).jpg
#   inflating: brain/train/Brain Tumor/Cancer (537).jpg
#   inflating: brain/train/Brain Tumor/Cancer (230).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1432).jpg
#   inflating: brain/train/Brain Tumor/Cancer (607).jpg
#   inflating: brain/train/Brain Tumor/Cancer (642).jpg
#   inflating: brain/train/Brain Tumor/Cancer (493).jpg
#   inflating: brain/train/Brain Tumor/Cancer (520).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2357).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1784).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2044).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1237).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1629).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1811).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1040).JPG
#   inflating: brain/train/Brain Tumor/Cancer (1675).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1507).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1863).jpg
#   inflating: brain/train/Brain Tumor/Cancer (600).jpg
#   inflating: brain/train/Brain Tumor/Cancer (16).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1194).jpg
#   inflating: brain/train/Brain Tumor/Cancer (173).jpg
#   inflating: brain/train/Brain Tumor/Cancer (881).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1284).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2413).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2241).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1366).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1560).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1482).jpg
#  extracting: brain/train/Brain Tumor/Cancer (2414).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1374).jpg
#   inflating: brain/train/Brain Tumor/Cancer (840).jpg
#   inflating: brain/train/Brain Tumor/Cancer (949).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2034).jpg
#   inflating: brain/train/Brain Tumor/Cancer (55).tif
#   inflating: brain/train/Brain Tumor/Cancer (804).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1218).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1164).jpg
#   inflating: brain/train/Brain Tumor/Cancer (135).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2363).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1431).jpg
#   inflating: brain/train/Brain Tumor/Cancer (243).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1324).jpg
#   inflating: brain/train/Brain Tumor/Cancer (907).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1124).jpg
#   inflating: brain/train/Brain Tumor/Cancer (151).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1901).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2332).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1397).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1377).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1992).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1866).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2060).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1898).jpg
#   inflating: brain/train/Brain Tumor/Cancer (155).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1786).jpg
#   inflating: brain/train/Brain Tumor/Cancer (674).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1494).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2420).jpg
#   inflating: brain/train/Brain Tumor/Cancer (467).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1764).jpg
#   inflating: brain/train/Brain Tumor/Cancer (885).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2371).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2183).jpg
#   inflating: brain/train/Brain Tumor/Cancer (94).jpg
#   inflating: brain/train/Brain Tumor/Cancer (17).jpg
#   inflating: brain/train/Brain Tumor/Cancer (319).jpg
#   inflating: brain/train/Brain Tumor/Cancer (568).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2078).jpg
#   inflating: brain/train/Brain Tumor/Cancer (677).jpg
#   inflating: brain/train/Brain Tumor/Cancer (569).jpg
#   inflating: brain/train/Brain Tumor/Cancer (888).jpg
#   inflating: brain/train/Brain Tumor/Cancer (821).jpg
#   inflating: brain/train/Brain Tumor/Cancer (131).jpg
#   inflating: brain/train/Brain Tumor/Cancer (548).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1525).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2351).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1762).jpg
#   inflating: brain/train/Brain Tumor/Cancer (110).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1777).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1918).jpg
#   inflating: brain/train/Brain Tumor/Cancer (8).tif
#   inflating: brain/train/Brain Tumor/Cancer (128).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2290).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1544).jpg
#   inflating: brain/train/Brain Tumor/Cancer (618).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1234).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1624).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1027).JPG
#   inflating: brain/train/Brain Tumor/Cancer (280).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1175).JPG
#   inflating: brain/train/Brain Tumor/Cancer (2061).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1243).jpg
#   inflating: brain/train/Brain Tumor/Cancer (601).jpg
#   inflating: brain/train/Brain Tumor/Cancer (882).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1441).jpg
#   inflating: brain/train/Brain Tumor/Cancer (148).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1320).jpg
#   inflating: brain/train/Brain Tumor/Cancer (662).jpg
#   inflating: brain/train/Brain Tumor/Cancer (748).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1235).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2204).jpg
#   inflating: brain/train/Brain Tumor/Cancer (158).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1298).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2391).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2254).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1911).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2087).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1570).jpg
#   inflating: brain/train/Brain Tumor/Cancer (593).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1746).jpg
#   inflating: brain/train/Brain Tumor/Cancer (41).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2421).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1384).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1709).jpg
#   inflating: brain/train/Brain Tumor/Cancer (193).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2346).jpg
#   inflating: brain/train/Brain Tumor/Cancer (9).jpg
#   inflating: brain/train/Brain Tumor/Cancer (867).jpg
#   inflating: brain/train/Brain Tumor/Cancer (403).jpg
#   inflating: brain/train/Brain Tumor/Cancer (266).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1106).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1745).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2179).jpg
#   inflating: brain/train/Brain Tumor/Cancer (2329).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1487).jpg
#   inflating: brain/train/Brain Tumor/Cancer (370).jpg
#   inflating: brain/train/Brain Tumor/Cancer (591).jpg
#   inflating: brain/train/Brain Tumor/Cancer (785).jpg
#   inflating: brain/train/Brain Tumor/Cancer (192).jpg
#   inflating: brain/train/Brain Tumor/Cancer (77).tif
#   inflating: brain/train/Brain Tumor/Cancer (214).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1246).jpg
#   inflating: brain/train/Brain Tumor/Cancer (702).jpg
#   inflating: brain/train/Brain Tumor/Cancer (920).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1014).jpg
#   inflating: brain/train/Brain Tumor/Cancer (234).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1024).JPG
#   inflating: brain/train/Brain Tumor/Cancer (237).jpg
#   inflating: brain/train/Brain Tumor/Cancer (56).jpg
#   inflating: brain/train/Brain Tumor/Cancer (1839).jpg

# %% [markdown]
# ## <b>3 <span style='color:#e61227'>|</span> Data Preparation </b>
#
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#e61227'>3.1 |</span></b> Splitting Dataset</b></p>
# </div>
#
# - We need to evaluate the model on validation datasets to track the model's performance during training. Then, We use 20% of the dataset for the **Validation set** and use the rest as the **Training set**, so we have an **80/20** split!

# %%
# Dataset Path
data_dir = '/content/brain'
data_dir = pathlib.Path(data_dir)

# %%
# define transformation
transform = transforms.Compose(
    [
        transforms.Resize((256,256)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.RandomRotation(30),
        transforms.ToTensor(),
        transforms.Normalize(mean = [0.485, 0.456, 0.406],std = [0.229, 0.224, 0.225])
   ]
)

# %% [markdown]
# ## <b>4 <span style='color:#e61227'>|</span> Image Augmentation Definitions</b>

# %%
# Define an object of the custom dataset for the train and validation.
train_set = torchvision.datasets.ImageFolder(data_dir.joinpath("train"), transform=transform)
train_set.transform
val_set = torchvision.datasets.ImageFolder(data_dir.joinpath("val"), transform=transform)
val_set.transform
# Out:
# Compose(
#     Resize(size=(256, 256), interpolation=bilinear, max_size=None, antialias=True)
#     RandomHorizontalFlip(p=0.5)
#     RandomVerticalFlip(p=0.5)
#     RandomRotation(degrees=[-30.0, 30.0], interpolation=nearest, expand=False, fill=0)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )

# %%
# Visualiztion some images from Train Set, half healthy and half tumor images
CLA_label = {
    0 : 'Brain Tumor',
    1 : 'Healthy'
}
figure = plt.figure(figsize=(10, 10))
cols, rows = 4, 4
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(train_set), size=(1,)).item()
    img, label = train_set[sample_idx]
    while i < 9 and label == 0:
      sample_idx = torch.randint(len(train_set), size=(1,)).item()
      img, label = train_set[sample_idx]
    while i >= 9 and label == 1:
      sample_idx = torch.randint(len(train_set), size=(1,)).item()
      img, label = train_set[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(CLA_label[label])
    plt.axis("off")
    img_np = img.numpy().transpose((1, 2, 0))
    # Clip pixel values to [0, 1]
    img_valid_range = np.clip(img_np, 0, 1)
    plt.imshow(img_valid_range)
    plt.suptitle('Brain Images', y=0.95)
plt.show()

# %% [markdown]
# ## <b>5 <span style='color:#e61227'>|</span> Creating Dataloaders</b>

# %%
# import and load train, validation
batch_size = 64

train_loader = torch.utils.data.DataLoader(train_set, batch_size = batch_size, shuffle = True, num_workers = 2)
val_loader = torch.utils.data.DataLoader(val_set, batch_size = batch_size, shuffle = True, num_workers = 2)

# %%
# print shape for Training data and Validation data
for key, value in {'Training data': train_loader, "Validation data": val_loader}.items():
    for X, y in value:
        print(f"{key}:")
        print(f"Shape of X : {X.shape}")
        print(f"Shape of y: {y.shape} {y.dtype}\n")
        break
# Out:
# Training data:
# Shape of X : torch.Size([64, 3, 256, 256])
# Shape of y: torch.Size([64]) torch.int64
#
# Validation data:
# Shape of X : torch.Size([64, 3, 256, 256])
# Shape of y: torch.Size([64]) torch.int64

# %% [markdown]
# ## <b>6 <span style='color:#e61227'>|</span> Define Brain Tumor Classifier</b>

# %%
'''This function can be useful in determining the output size of a convolutional layer in a neural network,
given the input dimensions and the convolutional layer's parameters. You may not use it in your code'''

def findConv2dOutShape(hin,win,conv,pool=2):
    # get conv arguments
    kernel_size = conv.kernel_size
    stride=conv.stride
    padding=conv.padding
    dilation=conv.dilation

    hout=np.floor((hin+2*padding[0]-dilation[0]*(kernel_size[0]-1)-1)/stride[0]+1)
    wout=np.floor((win+2*padding[1]-dilation[1]*(kernel_size[1]-1)-1)/stride[1]+1)

    if pool:
        hout/=pool
        wout/=pool
    return int(hout),int(wout)

# %%
# Define Architecture For CNN_TUMOR Model
class CNN_TUMOR(nn.Module):

    # Network Initialisation
    def __init__(self, params):

        super(CNN_TUMOR, self).__init__()

        Cin,Hin,Win = params["shape_in"]
        init_f = params["initial_filters"]
        num_fc1 = params["num_fc1"]
        num_classes = params["num_classes"]
        self.dropout_rate = params["dropout_rate"]

        # Convolution Layers
        self.conv1 = nn.Conv2d(Cin, init_f, kernel_size=3)
        h,w=findConv2dOutShape(Hin,Win,self.conv1)
        self.conv2 = nn.Conv2d(init_f, 2*init_f, kernel_size=3)
        h,w=findConv2dOutShape(h,w,self.conv2)
        self.conv3 = nn.Conv2d(2*init_f, 4*init_f, kernel_size=3)
        h,w=findConv2dOutShape(h,w,self.conv3)
        self.conv4 = nn.Conv2d(4*init_f, 8*init_f, kernel_size=3)
        h,w=findConv2dOutShape(h,w,self.conv4)

        # compute the flatten size
        self.num_flatten=h*w*8*init_f
        self.fc1 = nn.Linear(self.num_flatten, num_fc1)
        self.fc2 = nn.Linear(num_fc1, num_classes)

    def forward(self,X):

        # Convolution & Pool Layers
        X = F.relu(self.conv1(X));
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv3(X))
        X = F.max_pool2d(X, 2, 2)
        X = F.relu(self.conv4(X))
        X = F.max_pool2d(X, 2, 2)
        X = X.view(-1, self.num_flatten)
        X = F.relu(self.fc1(X))
        X = F.dropout(X, self.dropout_rate)
        X = self.fc2(X)
        return F.log_softmax(X, dim=1)

# %%
params_model={
        "shape_in": (3,256,256),
        "initial_filters": 8,
        "num_fc1": 100,
        "dropout_rate": 0.25,
        "num_classes": 2}

# Create instantiation of Network class
cnn_model = CNN_TUMOR(params_model)

# define computation hardware approach (GPU/CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = cnn_model.to(device)

# %%
# Model Summary for CNN Model
summary(cnn_model, input_size=(3, 256, 256),device=device.type)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            224
# ├─Conv2d: 1-2                            1,168
# ├─Conv2d: 1-3                            4,640
# ├─Conv2d: 1-4                            18,496
# ├─Linear: 1-5                            1,254,500
# ├─Linear: 1-6                            202
# =================================================================
# Total params: 1,279,230
# Trainable params: 1,279,230
# Non-trainable params: 0
# =================================================================
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ├─Conv2d: 1-1                            224
# ├─Conv2d: 1-2                            1,168
# ├─Conv2d: 1-3                            4,640
# ├─Conv2d: 1-4                            18,496
# ├─Linear: 1-5                            1,254,500
# ├─Linear: 1-6                            202
# =================================================================
# Total params: 1,279,230
# Trainable params: 1,279,230
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## <b>7 <span style='color:#e61227'>|</span> Loss Function Definition</b>

# %%
loss_func = nn.CrossEntropyLoss(reduction="sum")

# %% [markdown]
# ## <b>8 <span style='color:#e61227'>|</span> Optimiser Definition</b>

# %%
opt = optim.Adam(cnn_model.parameters(), lr=3e-4)
lr_scheduler = ReduceLROnPlateau(opt, mode='min',factor=0.5, patience=20,verbose=1)

# %% [markdown]
# ## <b>9 <span style='color:#e61227'>|</span> Training Model</b>

# %%
# Function to compute the loss value per batch of data
def loss_batch(loss_func, output, target, opt=None):

    loss = loss_func(output, target) # get loss
    pred = output.argmax(dim=1, keepdim=True) # Get Output Class
    metric_b=pred.eq(target.view_as(pred)).sum().item() # get performance metric

    if opt is not None:
        opt.zero_grad()
        loss.backward()
        opt.step()

    return loss.item(), metric_b

# Compute the loss value & performance metric for the entire dataset (epoch)
def loss_epoch(model,loss_func,dataset_dl,opt=None):

    run_loss=0.0
    t_metric=0.0
    len_data=len(dataset_dl.dataset)

    # internal loop over dataset
    for xb, yb in dataset_dl:
        # move batch to device
        xb=xb.to(device)
        yb=yb.to(device)
        output=model(xb) # get model output
        loss_b,metric_b=loss_batch(loss_func, output, yb, opt) # get loss per batch
        run_loss+=loss_b        # update running loss

        if metric_b is not None: # update running metric
            t_metric+=metric_b

    loss=run_loss/float(len_data)  # average loss value
    metric=t_metric/float(len_data) # average metric value

    return loss, metric

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#e61227'>9.2 |</span></b> Training Function</b></p>
# </div>

# %%
def Train_Val(model, train_dl, val_dl, epochs, opt, lr_scheduler, loss_func):

    # history of loss values in each epoch
    loss_history={"train": [],"val": []}
    # histroy of metric values in each epoch
    metric_history={"train": [],"val": []}
    # a deep copy of weights for the best performing model
    best_model_wts = copy.deepcopy(model.state_dict())
    # initialize best loss to a large value
    best_loss=float('inf')

# Train Model n_epochs (the progress of training by printing the epoch number and the associated learning rate. It can be helpful for debugging, monitoring the learning rate schedule, or gaining insights into the training process.)

    for epoch in tqdm(range(epochs)):

# Train Model Process

        model.train()
        train_loss, train_metric = loss_epoch(model,loss_func,train_dl,opt)

        # collect losses
        loss_history["train"].append(train_loss)
        metric_history["train"].append(train_metric)

# Evaluate Model Process

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model,loss_func,val_dl)

        # store best model
        if(val_loss < best_loss):
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())

        # collect loss and metric for validation dataset
        loss_history["val"].append(val_loss)
        metric_history["val"].append(val_metric)

        # learning rate schedule
        lr_scheduler.step(val_loss)

        print(f"train loss: {train_loss:.6f}, dev loss: {val_loss:.6f}, accuracy: {100*val_metric:.2f}")
        print("-"*10)

    # load best model weights
    model.load_state_dict(best_model_wts)

    return model, loss_history, metric_history

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#e61227'>9.3 |</span></b> Training Process </b></p>
# </div>

# %%
# Define parameters used for training and evaluation of a cnn_model
epochs = 20

# train and validate the model
cnn_model,loss_hist,metric_hist = Train_Val(cnn_model, train_loader, val_loader, epochs, opt, lr_scheduler, loss_func)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# train loss: 0.614838, dev loss: 0.551406, accuracy: 73.29
# ----------
# train loss: 0.490753, dev loss: 0.448298, accuracy: 79.70
# ----------
# train loss: 0.433915, dev loss: 0.413980, accuracy: 80.78
# ----------
# train loss: 0.417365, dev loss: 0.378949, accuracy: 83.06
# ----------
# train loss: 0.372599, dev loss: 0.379976, accuracy: 81.43
# ----------
# train loss: 0.356646, dev loss: 0.331331, accuracy: 85.67
# ----------
# train loss: 0.322673, dev loss: 0.331347, accuracy: 85.02
# ----------
# train loss: 0.321540, dev loss: 0.398233, accuracy: 82.19
# ----------
# train loss: 0.309392, dev loss: 0.296375, accuracy: 87.40
# ----------
# train loss: 0.285293, dev loss: 0.293640, accuracy: 86.54
# ----------
# train loss: 0.277502, dev loss: 0.263657, accuracy: 88.71
# ----------
# train loss: 0.256817, dev loss: 0.267498, accuracy: 87.84
# ----------
# train loss: 0.276905, dev loss: 0.266900, accuracy: 88.60
# ----------
# train loss: 0.235023, dev loss: 0.233416, accuracy: 90.77
# ----------
# train loss: 0.242705, dev loss: 0.229419, accuracy: 90.01
# ----------
# train loss: 0.222289, dev loss: 0.270604, accuracy: 87.40
# ----------
# train loss: 0.211647, dev loss: 0.265623, accuracy: 89.25
# ----------
# train loss: 0.202795, dev loss: 0.203930, accuracy: 91.75
# ----------
# train loss: 0.193355, dev loss: 0.185081, accuracy: 92.73
# ----------
# train loss: 0.178593, dev loss: 0.180935, accuracy: 92.40
# ----------

# %% [markdown]
# ## <b>10 <span style='color:#e61227'>|</span> Evaluation Metric Visualization </b>

# %%
# Convergence History Plot
fig,ax = plt.subplots(1,2,figsize=(12,5))

sns.lineplot(x=[*range(1,epochs+1)],y=loss_hist["train"],ax=ax[0],label='loss_hist["train"]')
sns.lineplot(x=[*range(1,epochs+1)],y=loss_hist["val"],ax=ax[0],label='loss_hist["val"]')
sns.lineplot(x=[*range(1,epochs+1)],y=metric_hist["train"],ax=ax[1],label='Acc_hist["train"]')
sns.lineplot(x=[*range(1,epochs+1)],y=metric_hist["val"],ax=ax[1],label='Acc_hist["val"]')
# Out:
# <Axes: >

# %% [markdown]
# <div style="color:white;display:fill;border-radius:8px;
#             background-color:#03112A;font-size:150%;
#             letter-spacing:1.0px;background-image: url(https://i.imgur.com/GVd0La1.png)">
#     <p style="padding: 8px;color:white;"><b><b><span style='color:#e61227'>10.2 |</span></b> Confusion_Matrix </b></p>
# </div>

# %%
# define function For Classification Report
def Ture_and_Pred(val_loader, model):
    i = 0
    y_true = []
    y_pred = []
    for images, labels in val_loader:
        images = images.to(device)
        labels = labels.numpy()
        outputs = model(images)
        _, pred = torch.max(outputs.data, 1)
        pred = pred.detach().cpu().numpy()

        y_true = np.append(y_true, labels)
        y_pred = np.append(y_pred, pred)

    return y_true, y_pred


# check confusion matrix for error analysis
y_true, y_pred = Ture_and_Pred(val_loader, cnn_model)

print(classification_report(y_true, y_pred), '\n\n')
cm = confusion_matrix(y_true, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.88      0.89       503
#          1.0       0.86      0.89      0.87       418
#
#     accuracy                           0.88       921
#    macro avg       0.88      0.88      0.88       921
# weighted avg       0.88      0.88      0.88       921

# %%
# Confusion Matrix Plotting Function
def show_confusion_matrix(cm, CLA_label, title='Confusion matrix', cmap=plt.cm.YlGnBu):

    plt.figure(figsize=(10,7))
    plt.grid(False)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(CLA_label))

    plt.xticks(tick_marks, [f"{value}={key}" for key , value in CLA_label.items()], rotation=45)
    plt.yticks(tick_marks, [f"{value}={key}" for key , value in CLA_label.items()])

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, f"{cm[i,j]}\n{cm[i,j]/np.sum(cm)*100:.2f}%", horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.tight_layout()
    plt.show()

show_confusion_matrix(cm, CLA_label)
